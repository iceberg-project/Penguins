# %% [markdown]
# # Model search
# ---

# %%
for lr in [1E-3, 1E-4, 1E-5]:
    for cycles in [2, 3, 4]:
        for is_binary in [1, 0]:
            if is_binary:
                loss_func = "BCE"
            else:
                loss_func = "SL1"
            for shannon in [0, 5, 7]:
                training_set = 'training_set'
                # !python train_model.py --t_dir=$training_set \
                                       --models_dir="saved_models" \
                                       --hyp_set="D" \
                                       --model_arch="U-Net_Area" \
                                       --binary_target=$is_binary \
                                       --lr=$lr \
                                       --num_cycles=$cycles \
                                       --loss_func=$loss_func \
                                       --num_epochs=1
# Out:
# ^C
# Process Process-2:
# Process Process-1:
# Traceback (most recent call last):
#   File "/home/bento/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bento/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/home/bento/anaconda3/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/bento/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/bento/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/bento/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/bento/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bento/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/home/bento/anaconda3/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/bento/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/bento/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/bento/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fc81e974908>>
# Traceback (most recent call last):
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 347, in __del__
#     def __del__(self):
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 178, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 13949) exited unexpectedly with exit code 1.
# Traceback (most recent call last):
#   File "train_model.py", line 237, in <module>
#     main()
#   File "train_model.py", line 233, in main
#     models_dir=args.models_dir, binary_target=args.binary_target)
#   File "train_model.py", line 131, in train_model
#     loss.backward()
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/tensor.py", line 93, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/autograd/__init__.py", line 89, in backward
#     allow_unreachable=True)  # allow_unreachable flag
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 40, in <module>
#     import numpy as _np
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/__init__.py", line 224, in <module>
#     _sanity_check()
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/__init__.py", line 216, in _sanity_check
#     if not abs(x.dot(x) - 2.0) < 1e-5:
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 78, in <module>
#     from torch._C import *
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 44, in <module>
#     if platform.system() == 'Windows':
#   File "/home/bento/anaconda3/lib/python3.6/platform.py", line 1068, in system
#     return uname().system
#   File "/home/bento/anaconda3/lib/python3.6/platform.py", line 1034, in uname
#     processor = _syscmd_uname('-p', '')
#   File "/home/bento/anaconda3/lib/python3.6/platform.py", line 791, in _syscmd_uname
#     output = f.read().strip()
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 78, in <module>
#     from torch._C import *
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/_vendor/packaging/version.py", line 31, in parse
#     return Version(version)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/_vendor/packaging/version.py", line 202, in __init__
#     raise InvalidVersion("Invalid version: '{0}'".format(version))
# pkg_resources.extern.packaging.version.InvalidVersion: Invalid version: '.egg-info'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "train_model.py", line 9, in <module>
#     from tensorboardX import SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/__init__.py", line 4, in <module>
#     from .writer import FileWriter, SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/writer.py", line 24, in <module>
#     from .src import event_pb2
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/src/event_pb2.py", line 6, in <module>
#     from google.protobuf import descriptor as _descriptor
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/google/protobuf/__init__.py", line 37, in <module>
#     __import__('pkg_resources').declare_namespace(__name__)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 3095, in <module>
#     @_call_aside
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 3079, in _call_aside
#     f(*args, **kwargs)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 3108, in _initialize_master_working_set
#     working_set = WorkingSet._build_master()
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 561, in _build_master
#     ws = cls()
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 554, in __init__
#     self.add_entry(entry)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 610, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 1954, in find_on_path
#     path_item_entries = _by_version_descending(filtered)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 1927, in _by_version_descending
#     return sorted(names, key=_by_version, reverse=True)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 1925, in _by_version
#     return [packaging.version.parse(part) for part in parts]
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 1925, in <listcomp>
#     return [packaging.version.parse(part) for part in parts]
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/_vendor/packaging/version.py", line 33, in parse
#     return LegacyVersion(version)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/_vendor/packaging/version.py", line 76, in __init__
#     self._key = _legacy_cmpkey(self._version)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/_vendor/packaging/version.py", line 149, in _legacy_cmpkey
#     while parts and parts[-1] == "00000000":
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 276, in <module>
#     import torch.nn
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/nn/modules/__init__.py", line 1, in <module>
#     from .module import Module
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py", line 6, in <module>
#     from ..backends.thnn import backend as thnn_backend
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/nn/backends/thnn.py", line 41, in <module>
#     _initialize_backend()
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/nn/backends/thnn.py", line 22, in _initialize_backend
#     from .._functions.thnn import _all_functions as _thnn_functions
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/nn/_functions/thnn/__init__.py", line 3, in <module>
#     from .auto import *
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/nn/_functions/thnn/auto.py", line 5, in <module>
#     from torch._thnn.utils import parse_header, THNN_H_PATH
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/_thnn/__init__.py", line 52, in <module>
#     _thnn_headers = parse_header(THNN_H_PATH)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/_thnn/utils.py", line 63, in parse_header
#     lines = f.read().split('\n')
# KeyboardInterrupt
# ^C
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 276, in <module>
#     import torch.nn
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/nn/modules/__init__.py", line 1, in <module>
#     from .module import Module
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py", line 6, in <module>
#     from ..backends.thnn import backend as thnn_backend
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/nn/backends/thnn.py", line 41, in <module>
#     _initialize_backend()
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/nn/backends/thnn.py", line 23, in _initialize_backend
#     from .._functions.rnn import RNN, \
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 658, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 577, in module_from_spec
#   File "<frozen importlib._bootstrap>", line 556, in _init_module_attrs
#   File "<frozen importlib._bootstrap>", line 409, in cached
#   File "<frozen importlib._bootstrap_external>", line 362, in _get_cached
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 78, in <module>
#     from torch._C import *
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 40, in <module>
#     import numpy as _np
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/__init__.py", line 142, in <module>
#     from . import add_newdocs
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/add_newdocs.py", line 13, in <module>
#     from numpy.lib import add_newdoc
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/lib/__init__.py", line 23, in <module>
#     from .npyio import *
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py", line 42, in <module>
#     class BagObj(object):
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 78, in <module>
#     from torch._C import *
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 9, in <module>
#     from tensorboardX import SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/__init__.py", line 4, in <module>
#     from .writer import FileWriter, SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/writer.py", line 24, in <module>
#     from .src import event_pb2
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/src/event_pb2.py", line 6, in <module>
#     from google.protobuf import descriptor as _descriptor
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/google/protobuf/__init__.py", line 37, in <module>
#     __import__('pkg_resources').declare_namespace(__name__)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 36, in <module>
#     import email.parser
#   File "/home/bento/anaconda3/lib/python3.6/email/parser.py", line 12, in <module>
#     from email.feedparser import FeedParser, BytesFeedParser
#   File "/home/bento/anaconda3/lib/python3.6/email/feedparser.py", line 27, in <module>
#     from email._policybase import compat32
#   File "/home/bento/anaconda3/lib/python3.6/email/_policybase.py", line 9, in <module>
#     from email.utils import _has_surrogates
#   File "/home/bento/anaconda3/lib/python3.6/email/utils.py", line 33, in <module>
#     from email._parseaddr import quote
#   File "/home/bento/anaconda3/lib/python3.6/email/_parseaddr.py", line 16, in <module>
#     import time, calendar
#   File "/home/bento/anaconda3/lib/python3.6/calendar.py", line 129, in <module>
#     class Calendar(object):
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 9, in <module>
#     from tensorboardX import SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/__init__.py", line 4, in <module>
#     from .writer import FileWriter, SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/writer.py", line 24, in <module>
#     from .src import event_pb2
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/src/event_pb2.py", line 6, in <module>
#     from google.protobuf import descriptor as _descriptor
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/google/protobuf/__init__.py", line 37, in <module>
#     __import__('pkg_resources').declare_namespace(__name__)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 77, in <module>
#     __import__('pkg_resources.extern.packaging.requirements')
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/_vendor/packaging/requirements.py", line 9, in <module>
#     from pkg_resources.extern.pyparsing import stringStart, stringEnd, originalTextFor, ParseException
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 656, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 626, in _load_backward_compatible
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/extern/__init__.py", line 43, in load_module
#     __import__(extant)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/_vendor/pyparsing.py", line 5342, in <module>
#     pythonStyleComment = Regex(r"#.*").setName("Python style comment")
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/_vendor/pyparsing.py", line 2751, in __init__
#     self.re = re.compile(self.pattern, self.flags)
#   File "/home/bento/anaconda3/lib/python3.6/re.py", line 233, in compile
#     return _compile(pattern, flags)
#   File "/home/bento/anaconda3/lib/python3.6/re.py", line 301, in _compile
#     p = sre_compile.compile(pattern, flags)
#   File "/home/bento/anaconda3/lib/python3.6/sre_compile.py", line 562, in compile
#     p = sre_parse.parse(p, flags)
#   File "/home/bento/anaconda3/lib/python3.6/sre_parse.py", line 850, in parse
#     pattern = Pattern()
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 40, in <module>
#     import numpy as _np
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/__init__.py", line 224, in <module>
#     _sanity_check()
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/__init__.py", line 216, in _sanity_check
#     if not abs(x.dot(x) - 2.0) < 1e-5:
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 78, in <module>
#     from torch._C import *
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 9, in <module>
#     from tensorboardX import SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/__init__.py", line 4, in <module>
#     from .writer import FileWriter, SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/writer.py", line 24, in <module>
#     from .src import event_pb2
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/src/event_pb2.py", line 6, in <module>
#     from google.protobuf import descriptor as _descriptor
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/google/protobuf/__init__.py", line 37, in <module>
#     __import__('pkg_resources').declare_namespace(__name__)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 3095, in <module>
#     @_call_aside
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 3079, in _call_aside
#     f(*args, **kwargs)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 3108, in _initialize_master_working_set
#     working_set = WorkingSet._build_master()
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 561, in _build_master
#     ws = cls()
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 554, in __init__
#     self.add_entry(entry)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 610, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 1954, in find_on_path
#     path_item_entries = _by_version_descending(filtered)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 1927, in _by_version_descending
#     return sorted(names, key=_by_version, reverse=True)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 1925, in _by_version
#     return [packaging.version.parse(part) for part in parts]
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 1925, in <listcomp>
#     return [packaging.version.parse(part) for part in parts]
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 40, in <module>
#     import numpy as _np
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/__init__.py", line 168, in <module>
#     from . import ma
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/ma/__init__.py", line 47, in <module>
#     from . import extras
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/ma/extras.py", line 1076, in <module>
#     def intersect1d(ar1, ar2, assume_unique=False):
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 9, in <module>
#     from tensorboardX import SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/__init__.py", line 4, in <module>
#     from .writer import FileWriter, SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/writer.py", line 24, in <module>
#     from .src import event_pb2
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/src/event_pb2.py", line 6, in <module>
#     from google.protobuf import descriptor as _descriptor
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/google/protobuf/__init__.py", line 37, in <module>
#     __import__('pkg_resources').declare_namespace(__name__)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 3095, in <module>
#     @_call_aside
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 3079, in _call_aside
#     f(*args, **kwargs)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 3123, in _initialize_master_working_set
#     for dist in working_set
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 3123, in <genexpr>
#     for dist in working_set
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 2631, in activate
#     for pkg in self._get_metadata('namespace_packages.txt'):
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 2621, in _get_metadata
#     for line in self.get_metadata_lines(name):
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 1404, in get_metadata_lines
#     return yield_lines(self.get_metadata(name))
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 1400, in get_metadata
#     value = self._get(self._fn(self.egg_info, name))
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 1512, in _get
#     with open(path, 'rb') as stream:
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 40, in <module>
#     import numpy as _np
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/__init__.py", line 142, in <module>
#     from . import add_newdocs
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/add_newdocs.py", line 13, in <module>
#     from numpy.lib import add_newdoc
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/lib/__init__.py", line 9, in <module>
#     from .index_tricks import *
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/lib/index_tricks.py", line 13, in <module>
#     import numpy.matrixlib as matrixlib
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/matrixlib/__init__.py", line 6, in <module>
#     from .defmatrix import *
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/matrixlib/defmatrix.py", line 6, in <module>
#     import ast
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 779, in get_code
#   File "<frozen importlib._bootstrap_external>", line 487, in _compile_bytecode
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 14, in <module>
#     from utils.dataloaders.transforms import TransformPair
#   File "/home/bento/Penguins/utils/dataloaders/transforms.py", line 1, in <module>
#     import torchvision.transforms.functional as TF
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 656, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 626, in _load_backward_compatible
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/__init__.py", line 1, in <module>
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 656, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 626, in _load_backward_compatible
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/models/__init__.py", line 1, in <module>
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 656, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 626, in _load_backward_compatible
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/models/alexnet.py", line 2, in <module>
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/utils/model_zoo.py", line 11, in <module>
#     from requests.utils import urlparse
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/requests/__init__.py", line 95, in <module>
#     from urllib3.contrib import pyopenssl
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py", line 46, in <module>
#     import OpenSSL.SSL
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/OpenSSL/__init__.py", line 8, in <module>
#     from OpenSSL import crypto, SSL
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/OpenSSL/crypto.py", line 12, in <module>
#     from cryptography import x509
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/cryptography/x509/__init__.py", line 8, in <module>
#     from cryptography.x509.base import (
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/cryptography/x509/base.py", line 15, in <module>
#     from cryptography.hazmat.primitives.asymmetric import dsa, ec, rsa
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/cryptography/hazmat/primitives/asymmetric/ec.py", line 319, in <module>
#     class ECDSA(object):
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 40, in <module>
#     import numpy as _np
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/__init__.py", line 142, in <module>
#     from . import add_newdocs
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/add_newdocs.py", line 13, in <module>
#     from numpy.lib import add_newdoc
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/lib/__init__.py", line 8, in <module>
#     from .type_check import *
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/lib/type_check.py", line 11, in <module>
#     import numpy.core.numeric as _nx
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/core/__init__.py", line 74, in <module>
#     from numpy.testing import _numpy_tester
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/testing/__init__.py", line 12, in <module>
#     from . import decorators as dec
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/testing/decorators.py", line 6, in <module>
#     from .nose_tools.decorators import *
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/testing/nose_tools/decorators.py", line 20, in <module>
#     from .utils import SkipTest, assert_warns
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/testing/nose_tools/utils.py", line 15, in <module>
#     from tempfile import mkdtemp, mkstemp
#   File "/home/bento/anaconda3/lib/python3.6/tempfile.py", line 45, in <module>
#     from random import Random as _Random
#   File "/home/bento/anaconda3/lib/python3.6/random.py", line 46, in <module>
#     from hashlib import sha512 as _sha512
#   File "/home/bento/anaconda3/lib/python3.6/hashlib.py", line 160, in <module>
#     import _hashlib
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 9, in <module>
#     from tensorboardX import SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/__init__.py", line 4, in <module>
#     from .writer import FileWriter, SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/writer.py", line 24, in <module>
#     from .src import event_pb2
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/src/event_pb2.py", line 6, in <module>
#     from google.protobuf import descriptor as _descriptor
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/google/protobuf/descriptor.py", line 40, in <module>
#     from google.protobuf.internal import api_implementation
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/google/protobuf/internal/api_implementation.py", line 40, in <module>
#     from google.protobuf.internal import _api_implementation
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 78, in <module>
#     from torch._C import *
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 9, in <module>
#     from tensorboardX import SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/__init__.py", line 4, in <module>
#     from .writer import FileWriter, SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/writer.py", line 24, in <module>
#     from .src import event_pb2
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/src/event_pb2.py", line 6, in <module>
#     from google.protobuf import descriptor as _descriptor
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/google/protobuf/__init__.py", line 37, in <module>
#     __import__('pkg_resources').declare_namespace(__name__)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 36, in <module>
#     import email.parser
#   File "/home/bento/anaconda3/lib/python3.6/email/parser.py", line 12, in <module>
#     from email.feedparser import FeedParser, BytesFeedParser
#   File "/home/bento/anaconda3/lib/python3.6/email/feedparser.py", line 27, in <module>
#     from email._policybase import compat32
#   File "/home/bento/anaconda3/lib/python3.6/email/_policybase.py", line 9, in <module>
#     from email.utils import _has_surrogates
#   File "/home/bento/anaconda3/lib/python3.6/email/utils.py", line 267, in <module>
#     re.ASCII)
#   File "/home/bento/anaconda3/lib/python3.6/re.py", line 233, in compile
#     return _compile(pattern, flags)
#   File "/home/bento/anaconda3/lib/python3.6/re.py", line 301, in _compile
#     p = sre_compile.compile(pattern, flags)
#   File "/home/bento/anaconda3/lib/python3.6/sre_compile.py", line 562, in compile
#     p = sre_parse.parse(p, flags)
#   File "/home/bento/anaconda3/lib/python3.6/sre_parse.py", line 855, in parse
#     p = _parse_sub(source, pattern, flags & SRE_FLAG_VERBOSE, 0)
#   File "/home/bento/anaconda3/lib/python3.6/sre_parse.py", line 416, in _parse_sub
#     not nested and not items))
#   File "/home/bento/anaconda3/lib/python3.6/sre_parse.py", line 770, in _parse
#     state.closegroup(group, p)
#   File "/home/bento/anaconda3/lib/python3.6/sre_parse.py", line 97, in closegroup
#     self.groupwidths[gid] = p.getwidth()
#   File "/home/bento/anaconda3/lib/python3.6/sre_parse.py", line 219, in getwidth
#     self.width = min(lo, MAXREPEAT - 1), min(hi, MAXREPEAT)
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 74, in <module>
#     import torch._nvrtc
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 78, in <module>
#     from torch._C import *
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 9, in <module>
#     from tensorboardX import SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/__init__.py", line 4, in <module>
#     from .writer import FileWriter, SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/writer.py", line 24, in <module>
#     from .src import event_pb2
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/src/event_pb2.py", line 6, in <module>
#     from google.protobuf import descriptor as _descriptor
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/google/protobuf/__init__.py", line 37, in <module>
#     __import__('pkg_resources').declare_namespace(__name__)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 36, in <module>
#     import email.parser
#   File "/home/bento/anaconda3/lib/python3.6/email/parser.py", line 12, in <module>
#     from email.feedparser import FeedParser, BytesFeedParser
#   File "/home/bento/anaconda3/lib/python3.6/email/feedparser.py", line 27, in <module>
#     from email._policybase import compat32
#   File "/home/bento/anaconda3/lib/python3.6/email/_policybase.py", line 9, in <module>
#     from email.utils import _has_surrogates
#   File "/home/bento/anaconda3/lib/python3.6/email/utils.py", line 33, in <module>
#     from email._parseaddr import quote
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 779, in get_code
#   File "<frozen importlib._bootstrap_external>", line 487, in _compile_bytecode
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 78, in <module>
#     from torch._C import *
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 14, in <module>
#     from utils.dataloaders.transforms import TransformPair
#   File "/home/bento/Penguins/utils/dataloaders/transforms.py", line 1, in <module>
#     import torchvision.transforms.functional as TF
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 656, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 626, in _load_backward_compatible
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/__init__.py", line 1, in <module>
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 656, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 626, in _load_backward_compatible
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/models/__init__.py", line 1, in <module>
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 656, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 626, in _load_backward_compatible
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/models/alexnet.py", line 2, in <module>
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/utils/model_zoo.py", line 11, in <module>
#     from requests.utils import urlparse
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/requests/__init__.py", line 95, in <module>
#     from urllib3.contrib import pyopenssl
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py", line 48, in <module>
#     from cryptography.hazmat.backends.openssl import backend as openssl_backend
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/cryptography/hazmat/backends/openssl/__init__.py", line 7, in <module>
#     from cryptography.hazmat.backends.openssl.backend import backend
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/cryptography/hazmat/backends/openssl/backend.py", line 100, in <module>
#     class Backend(object):
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/cryptography/hazmat/backends/openssl/backend.py", line 132, in Backend
#     @contextlib.contextmanager
#   File "/home/bento/anaconda3/lib/python3.6/contextlib.py", line 157, in contextmanager
#     @wraps(func)
#   File "/home/bento/anaconda3/lib/python3.6/functools.py", line 67, in update_wrapper
#     getattr(wrapper, attr).update(getattr(wrapped, attr, {}))
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 40, in <module>
#     import numpy as _np
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/__init__.py", line 142, in <module>
#     from . import add_newdocs
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/add_newdocs.py", line 13, in <module>
#     from numpy.lib import add_newdoc
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/lib/__init__.py", line 9, in <module>
#     from .index_tricks import *
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/lib/index_tricks.py", line 13, in <module>
#     import numpy.matrixlib as matrixlib
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/matrixlib/__init__.py", line 6, in <module>
#     from .defmatrix import *
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/matrixlib/defmatrix.py", line 6, in <module>
#     import ast
#   File "/home/bento/anaconda3/lib/python3.6/ast.py", line 27, in <module>
#     from _ast import *
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 78, in <module>
#     from torch._C import *
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 40, in <module>
#     import numpy as _np
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/__init__.py", line 165, in <module>
#     from . import polynomial
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/numpy/polynomial/__init__.py", line 18, in <module>
#     from .polynomial import Polynomial
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 7, in <module>
#     import torch
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/torch/__init__.py", line 78, in <module>
#     from torch._C import *
# KeyboardInterrupt
# ^C
# Traceback (most recent call last):
#   File "train_model.py", line 9, in <module>
#     from tensorboardX import SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/__init__.py", line 4, in <module>
#     from .writer import FileWriter, SummaryWriter
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/writer.py", line 24, in <module>
#     from .src import event_pb2
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/tensorboardX/src/event_pb2.py", line 6, in <module>
#     from google.protobuf import descriptor as _descriptor
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/google/protobuf/__init__.py", line 37, in <module>
#     __import__('pkg_resources').declare_namespace(__name__)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/__init__.py", line 77, in <module>
#     __import__('pkg_resources.extern.packaging.requirements')
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/_vendor/packaging/requirements.py", line 9, in <module>
#     from pkg_resources.extern.pyparsing import stringStart, stringEnd, originalTextFor, ParseException
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 656, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 626, in _load_backward_compatible
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/extern/__init__.py", line 43, in load_module
#     __import__(extant)
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/_vendor/pyparsing.py", line 4715, in <module>
#     _escapedPunc = Word( _bslash, r"\[]-*.$+^?()~ ", exact=2 ).setParseAction(lambda s,l,t:t[0][1])
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/_vendor/pyparsing.py", line 1261, in setParseAction
#     self.parseAction = list(map(_trim_arity, list(fns)))
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/_vendor/pyparsing.py", line 1043, in _trim_arity
#     this_line = extract_stack(limit=2)[-1]
#   File "/home/bento/anaconda3/lib/python3.6/site-packages/pkg_resources/_vendor/pyparsing.py", line 1027, in extract_stack
#     frame_summary = traceback.extract_stack(limit=-offset+limit-1)[offset]
#   File "/home/bento/anaconda3/lib/python3.6/traceback.py", line 211, in extract_stack
#     stack = StackSummary.extract(walk_stack(f), limit=limit)
#   File "/home/bento/anaconda3/lib/python3.6/traceback.py", line 364, in extract
#     f.line
#   File "/home/bento/anaconda3/lib/python3.6/traceback.py", line 286, in line
#     self._line = linecache.getline(self.filename, self.lineno).strip()
#   File "/home/bento/anaconda3/lib/python3.6/linecache.py", line 16, in getline
#     lines = getlines(filename, module_globals)
#   File "/home/bento/anaconda3/lib/python3.6/linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "/home/bento/anaconda3/lib/python3.6/linecache.py", line 137, in updatecache
#     lines = fp.readlines()
#   File "/home/bento/anaconda3/lib/python3.6/codecs.py", line 318, in decode
#     def decode(self, input, final=False):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     155             else:
# --> 156                 child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     157             flush = sys.stdout.flush
#
# ~/anaconda3/lib/python3.6/site-packages/pexpect/pty_spawn.py in __init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions, use_poll)
#     189         super(spawn, self).__init__(timeout=timeout, maxread=maxread, searchwindowsize=searchwindowsize,
# --> 190                                     logfile=logfile, encoding=encoding, codec_errors=codec_errors)
#     191         self.STDIN_FILENO = pty.STDIN_FILENO
#
# ~/anaconda3/lib/python3.6/site-packages/pexpect/spawnbase.py in __init__(self, timeout, maxread, searchwindowsize, logfile, encoding, codec_errors)
#      93                 self.linesep = os.linesep.encode('ascii')
# ---> 94                 def write_to_stdout(b):
#      95                     try:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-3-e6ad2519cd11> in <module>()
#       8             for shannon in [0, 5, 7]:
#       9                 training_set = 'training_set'
# ---> 10                 get_ipython().system('python train_model.py --t_dir=$training_set                                        --models_dir="saved_models"                                        --hyp_set="D"                                        --model_arch="U-Net_Area"                                        --binary_target=$is_binary                                        --lr=$lr                                        --num_cycles=$cycles                                        --loss_func=$loss_func                                        --num_epochs=1')
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in system_piped(self, cmd)
#    2259         # a non-None value would trigger :func:`sys.displayhook` calls.
#    2260         # Instead, we store the exit_code in user_ns.
# -> 2261         self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#    2262
#    2263     def system_raw(self, cmd):
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     170             # (the character is known as ETX for 'End of Text', see
#     171             # curses.ascii.ETX).
# --> 172             child.sendline(chr(3))
#     173             # Read and print any more output the program might produce on its
#     174             # way out.
#
# UnboundLocalError: local variable 'child' referenced before assignment
